# %% [markdown]
# ## TBD Code reading, Below is a from-scratch  3 layer neural network. Main training code is in the *fit* method

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.datasets import mnist
from keras.utils import np_utils
# %matplotlib inline

plt.rcParams['figure.figsize'] = (5.0, 4.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
def relu(Z):
    """
    Rectified Linear Unit (relu Function) x if x > 0 else x

    :param Z: input tensor
    :return:  Relu output
    """
    A = np.maximum(0, Z)
    return A

def sigmoid(Z):
    """
    Sigmoid Function
    :param Z: input tensor
    :return: Sigmoid output
    """
    A = 1 / (1 + np.exp(-Z))
    return A


def relu_backward(dA, Z):
    """
    Derivative of relu function

    :param dA:  How cost changes with activation ( dJ_by_dA )
    :param Z:
 
    :return:  How cost changes with weighted sum (Z) ( dJ_by_dZ )
    """

    dZ = np.array(dA, copy=True) 

    dZ[Z <= 0] = 0

    return dZ


def sigmoid_backward(dA, Z):
    """
    Derivative of sigmoid function

    :param dA: How cost changes with activation ( dJ_by_dA )
    :param Z:
    
    :return: How cost changes with weighted sum (Z) ( dJ_by_dZ )
    """

    s = 1 / (1 + np.exp(-Z))
    dZ = dA * s * (1 - s)

    return dZ

# %%
# def init_weights(n_x, n_h1, n_h2, n_y):
def init_weights(layers_confs):
    """

    Initialize weights tensor

    :param n_x: size of the input layer
    :param n_h1: size of the hidden layer 1
    :param n_h2: size of the hidden layer 2
    :param n_y: size of the output layer

    :return:     weights -- python dictionary containing initialized weights:
                    W1 -- weight matrix of shape (n_h1, n_x)
                    b1 -- bias vector of shape (n_h1, 1)
                    W2 -- weight matrix of shape (n_h2, n_h1)
                    b2 -- bias vector of shape (n_h2, 1)
                    W3 -- weight matrix of shape (n_y, yon_h2)
                    b3 -- bias vector of shape (n_y, 1)
    """

    np.random.seed(1)
    L = len(layers_confs)
    weights = {}

    for i in range(L-1):
        weights["W" + str(i + 1)] = np.random.randn(layers_confs[i+1][0], layers_confs[i][0]) * 0.01
        weights["b" + str(i + 1)] = np.zeros((layers_confs[i+1][0], 1))

    # W1 = np.random.randn(n_h1, n_x) * 0.01
    # b1 = np.zeros((n_h1, 1))
    # W2 = np.random.randn(n_h2, n_h1) * 0.01
    # b2 = np.zeros((n_h2, 1))
    # W3 = np.random.randn(n_y, n_h2) * 0.01
    # b3 = np.zeros((n_y, 1))

    # weights = { "W1": W1, "b1": b1, "W2": W2, "b2": b2, "W3": W3, "b3": b3 }

    return weights

# %%
def step_forward(A, W, b, activation_function):
    """
    Step forward one layer in a deep neural network

    :param A: Input tensor for the layer
    :param W: Weight tensor for the layer
    :param b: Bias tensor for the layer
    :param activation_function: Activation function to be applied to the layer

    :return: Output Activation tensor and Weighted sum
    """

    Z = np.matmul(W, A) + b
    A_next = activation_function(Z)

    return A_next, Z


def compute_cost(AL, Y):
    """

    Cross Entropy Error (Cost) between Y-Hat and Y  (Y-Hat is activation of Lth Layer hence AL)

    :param AL: Activation of Lth Layer i.e Y-Hat
    :param Y: Actual Labels (Ground Truth)

    :return: Cost (How close are we?)

    """
    
    m = Y.shape[1]
    cost = -(np.sum(Y * np.log(AL) + (1 - Y) * np.log(1 - AL))) / m
    cost = np.squeeze(cost)

    return cost


def step_backward(dA, Z, A_prev, W, b, activation_function_backward):
    """
    Step back one layer in deep neural network,
    i.e Find out how much adjustment is needed in weights in this layer

    :param dA: How Final cost changes with Activation of this layer ( dJ_by_dA )
    :param Z: Weighted Sum from this layer
    :param A_prev: Incoming activations to this layer
    :param W: Weights of this layer
    :param b: Bias of this layer
    :param activation_function_backward:
    
    :return:
        dA_prev : How cost changes with activation from prev layer ( dJ_by_dA_prev), need this for further back propagation of cost to previous layer
        dW: How cost changes with weights of this layer (our prize). (dJ_by_dW)
        db: How cost changes with weights of this layer (dJ_by_db)
    """

    dZ = activation_function_backward(dA, Z)

    N = A_prev.shape[1]

    dW = np.matmul(dZ, A_prev.transpose()) / N
    db = np.sum(dZ, axis=1, keepdims=True) / N
    dA_prev = np.matmul(W.transpose(), dZ)

    return dA_prev, dW, db


def update_weights(weights, grads, learning_rate):
    """
    Update weights across all layers
    After our back-propogation we know how much weight & bias adjustment is needed
    in each layer, This function performs that update.

    :param weights: Original weights
    :param grads: Changes that needs to be made to weights (dW and db s)
    :param learning_rate: learning rate of algorithm. (a step length in gradient descent)

    :return: updated weights
    """
    L = len(weights)//2    # number of layers in the neural network

    for l in range(L):
        weights["W" + str(l + 1)] = weights["W" + str(l + 1)] - learning_rate * grads["dW" + str(l + 1)]
        weights["b" + str(l + 1)] = weights["b" + str(l + 1)] - learning_rate * grads["db" + str(l + 1)]

    return weights

# %% [markdown]
# ## Fit (Training of Neural network using back propagation and gradient descent )
# <img src="../../img/nn_training_loop.png" alt="drawing" width="400"/>

# %%
def fit(X, Y, layers_confs, learning_rate=0.0075, num_iterations=10000, print_cost=False):
    """
    Trains a 3 layer neural network

    :param X: input features
    :param Y: output labels
    :param layers_dims: number of nodes in each layer ( inputs, number of neurons in each hidden layer, output)
    :param learning_rate: 
    :param num_iterations:
    :param print_cost: 

    :return: Weights and Bias of the trained network. 

    """
    np.random.seed(1)
    grads = {}
    costs = []  # to keep track of the cost
    m = X.shape[1]  # number of examples
    
    # (n_x, n_h1, n_h2, n_y) = layers_confs
    # weights = init_weights(n_x, n_h1, n_h2, n_y)

    weights = init_weights(layers_confs)
    num_layers = len(layers_confs)

    def backwards(function):
        if function == relu:
            return relu_backward
        elif function == sigmoid:
            return sigmoid_backward

    functions = []
    activations = []
    weighted_sums = []
    dA = []

    # Set first activation to X
    activations.append(X)
    dA.append(np.zeros((64, 1)))

    for l in range(num_layers-1):
        functions.append(layers_confs[l+1][1])
        activations.append(np.zeros((layers_confs[l+1][0], 1)))
        weighted_sums.append(np.zeros((layers_confs[l+1][0], 1)))
        dA.append(np.zeros((64, 1)))
    
    for i in range(0, num_iterations):

        # Iterate through all layers forward
        for a in range(num_layers-1):
            activations[a+1], weighted_sums[a] = step_forward(activations[a],
            weights["W"+str(a+1)], weights["b"+str(a+1)], functions[a])

        # W1 = weights["W1"]
        # b1 = weights["b1"]
        # W2 = weights["W2"]
        # b2 = weights["b2"]
        # W3 = weights["W3"]
        # b3 = weights["b3"]

        # A1, Z1  = step_forward(X, W1, b1, relu)
        # A2, Z2  = step_forward(A1, W2, b2, relu)
        # A3, Z3  = step_forward(A2, W3, b3, sigmoid)

        cost = compute_cost(activations[-1], Y)

        # Initializing backward propagation
        dA[-1] = - (np.divide(Y, activations[-1]) - np.divide(1 - Y, 1 - activations[-1]))

        # gradient descent through back propagation

        for b in range(num_layers-1, 0, -1):
            dA[b-1], grads["dW"+str(b)], grads["db"+str(b)] = step_backward(dA[b], weighted_sums[b-1], activations[b-1],
            weights["W"+str(b)], weights["b"+str(b)], backwards(functions[b-1]))
            
        # dA2, dW3, db3 = step_backward(dA3, Z3, A2, W3, b3, sigmoid_backward)
        # dA1, dW2, db2 = step_backward(dA2, Z2, A1, W2, b2, relu_backward)
        # dA0, dW1, db1 = step_backward(dA1, Z1, X, W1, b1,  relu_backward)

        # grads['dW1'] = dW1
        # grads['db1'] = db1
        # grads['dW2'] = dW2
        # grads['db2'] = db2
        # grads['dW3'] = dW3
        # grads['db3'] = db3

        # Update weights.
        weights = update_weights(weights, grads, learning_rate)

        # Print the cost every 100 training example
        if print_cost and i % 100 == 0:
            print("Cost after iteration {}: {}".format(i, np.squeeze(cost)))
        if print_cost and i % 100 == 0:
            costs.append(cost)

    # plot the cost

    plt.plot(np.squeeze(costs))
    plt.ylabel('cost')
    plt.xlabel('iterations (per tens)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()

    return weights

# %% [markdown]
# ## Predict and Accuracy

# %%
def predict(X, weights, layers_confs):
    """
    Given weights of deep neural network, predict the output for X

    :param X: input tensor
    :param weights: Weights and Bias of the network
    :return:
    """
    num_layers = len(layers_confs)

    functions = []
    activations = []
    weighted_sums = []
    dA = []

    # Set first activation to X
    activations.append(X)
    dA.append(np.zeros((1, 1)))

    for l in range(num_layers-1):
        functions.append(layers_confs[l+1][1])
        activations.append(np.zeros((layers_confs[l+1][0], 1)))
        weighted_sums.append(np.zeros((layers_confs[l+1][0], 1)))
        dA.append(np.zeros((1, 1)))

    for a in range(num_layers-1):
        activations[a+1], weighted_sums[a] = step_forward(activations[a],
        weights["W"+str(a+1)], weights["b"+str(a+1)], functions[a])

    # W1 = weights["W1"]
    # b1 = weights["b1"]
    # W2 = weights["W2"]
    # b2 = weights["b2"]
    # W3 = weights["W3"]
    # b3 = weights["b3"]

    # A1, Z1 = step_forward(X, W1, b1, relu)
    # A2, Z2 = step_forward(A1, W2, b2, relu)
    # A3, Z3 = step_forward(A2, W3, b3, sigmoid)
    # A3 = np.around(A3)

    A3 = np.around(activations[-1])
    return A3


def compute_accuracy(X, Y, weights, layers_confs):
    """
    Compute predictions for X given the weights and then find out how accurate are the predictions
    by comparing with y

    :param X: Input Tensors to be predicted
    :param Y: Ground Truth Labels
    :param weights: Weight (Model)
    :return:
    """

    N = X.shape[1]
    A3 = predict(X, weights, layers_confs)
    res = A3 == Y
    accuracy = np.sum(res.all(axis=0)) / N
    print("Accuracy: " + str(accuracy))
    return accuracy

# %% [markdown]
# ## Train on sklearn MNIST data
# input = 8X8 pixels

# %%
# Preparing the digits dataset
digits = datasets.load_digits()


X = digits.data

# One hot encoding of target (Y)
Y = np_utils.to_categorical(digits.target, 10)

# Train test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# Transposing the input/output data as implementation expects them to be
# In Library implementations its usually the weights which are transposed

X_train = np.transpose(X_train)
X_test = np.transpose(X_test)
Y_train = np.transpose(Y_train)
Y_test = np.transpose(Y_test)

# n_x = 64
# n_h1 = 40
# n_h2 = 20
# n_y = 10
# layers_confs = (n_x, n_h1, n_h2, n_y)

input_layer = (64, None)
h1 = (40, relu)
h2 = (20, relu)
output_layer = (10, sigmoid)
layers_confs = [input_layer, h1, h2, output_layer]

weights = fit(X_train, Y_train, layers_confs, num_iterations = 10000, print_cost=True)
# Out:
# Cost after iteration 0: 6.927758213084503
# Cost after iteration 100: 3.2734321092361194
# Cost after iteration 200: 3.272013882242851
# Cost after iteration 300: 3.27077045635114
# Cost after iteration 400: 3.2694525244001924
# Cost after iteration 500: 3.267752714442069
# Cost after iteration 600: 3.2650325127930517
# Cost after iteration 700: 3.25941325638326
# Cost after iteration 800: 3.242932399332582
# Cost after iteration 900: 3.162153346617937
# Cost after iteration 1000: 2.751484626298503
# Cost after iteration 1100: 2.273013126644805
# Cost after iteration 1200: 1.9297770181872402
# Cost after iteration 1300: 1.5725724533918406
# Cost after iteration 1400: 1.3669183679538262
# Cost after iteration 1500: 1.2266482390271325
# Cost after iteration 1600: 1.1015916303678441
# Cost after iteration 1700: 0.9847125396257518
# Cost after iteration 1800: 0.8746599979896628
# Cost after iteration 1900: 0.7741030663294606
# Cost after iteration 2000: 0.6834265317759505
# Cost after iteration 2100: 0.6021422148264026
# Cost after iteration 2200: 0.5316391102076772
# Cost after iteration 2300: 0.4733549624099463
# Cost after iteration 2400: 0.42542233127926665
# Cost after iteration 2500: 0.3837042703091762
# Cost after iteration 2600: 0.35067634484249577
# Cost after iteration 2700: 0.32350769569384313
# Cost after iteration 2800: 0.30078128348618266
# Cost after iteration 2900: 0.2811230210453182
# Cost after iteration 3000: 0.2639074653565233
# Cost after iteration 3100: 0.24877298490566122
# Cost after iteration 3200: 0.23524486113931403
# Cost after iteration 3300: 0.22277045315154528
# Cost after iteration 3400: 0.21128002229568046
# Cost after iteration 3500: 0.20065768894395988
# Cost after iteration 3600: 0.19075788924194856
# Cost after iteration 3700: 0.18143451173844768
# Cost after iteration 3800: 0.17259179080353704
# Cost after iteration 3900: 0.16425595095751863
# Cost after iteration 4000: 0.1563118963735212
# Cost after iteration 4100: 0.14876585256988137
# Cost after iteration 4200: 0.1415303593716544
# Cost after iteration 4300: 0.1345559177284631
# Cost after iteration 4400: 0.127993194448778
# Cost after iteration 4500: 0.12187146498460397
# Cost after iteration 4600: 0.1160850230005627
# Cost after iteration 4700: 0.11044128621228382
# Cost after iteration 4800: 0.1051389781830947
# Cost after iteration 4900: 0.1001773953852384
# Cost after iteration 5000: 0.09557525036008144
# Cost after iteration 5100: 0.09128228743903276
# Cost after iteration 5200: 0.08726065276376692
# Cost after iteration 5300: 0.08340694250864358
# Cost after iteration 5400: 0.07980851764486868
# Cost after iteration 5500: 0.07642963666232233
# Cost after iteration 5600: 0.07324870681580398
# Cost after iteration 5700: 0.07026942348255469
# Cost after iteration 5800: 0.06746033154547
# Cost after iteration 5900: 0.0648461400340059
# Cost after iteration 6000: 0.06238632975905935
# Cost after iteration 6100: 0.06007361538275466
# Cost after iteration 6200: 0.05788874578958239
# Cost after iteration 6300: 0.055815900246843554
# Cost after iteration 6400: 0.05384566971970607
# Cost after iteration 6500: 0.0519802291024119
# Cost after iteration 6600: 0.05021024928772911
# Cost after iteration 6700: 0.048528122120043926
# Cost after iteration 6800: 0.04693136752244755
# Cost after iteration 6900: 0.045420533446445435
# Cost after iteration 7000: 0.043971411666290774
# Cost after iteration 7100: 0.04260277461327015
# Cost after iteration 7200: 0.041293789542649624
# Cost after iteration 7300: 0.04003510531324837
# Cost after iteration 7400: 0.03883946965052852
# Cost after iteration 7500: 0.037699309238380004
# Cost after iteration 7600: 0.0366027674766662
# Cost after iteration 7700: 0.035558682724403365
# Cost after iteration 7800: 0.03455336673008043
# Cost after iteration 7900: 0.033595266541984
# Cost after iteration 8000: 0.03268178767191662
# Cost after iteration 8100: 0.03179165822693583
# Cost after iteration 8200: 0.03094591287616839
# Cost after iteration 8300: 0.030140901599732723
# Cost after iteration 8400: 0.029360166680560715
# Cost after iteration 8500: 0.028614941936819484
# Cost after iteration 8600: 0.027901049262292338
# Cost after iteration 8700: 0.02721070993619492
# Cost after iteration 8800: 0.026544202636827104
# Cost after iteration 8900: 0.025905886646726748
# Cost after iteration 9000: 0.02529087771283753
# Cost after iteration 9100: 0.0246928080424596
# Cost after iteration 9200: 0.024117909879994553
# Cost after iteration 9300: 0.02356203416786295
# Cost after iteration 9400: 0.023026208310163263
# Cost after iteration 9500: 0.022504566861478007
# Cost after iteration 9600: 0.022005306331608063
# Cost after iteration 9700: 0.021511518715627873
# Cost after iteration 9800: 0.02103680326489943
# Cost after iteration 9900: 0.020579615702406358

# %% [markdown]
# ## Predict and compute accuracy

# %%
accuracy_train = compute_accuracy(X_train, Y_train, weights, layers_confs)
accuracy_test = compute_accuracy(X_test, Y_test, weights, layers_confs)
# Out:
# Accuracy: 0.9992576095025983
# Accuracy: 0.9511111111111111

# %% [markdown]
# ## TBD: Show some images for which the model makes errors

# %%
import matplotlib.pyplot as plt
def show_image(image, label):
    plt.figure(figsize=(3,2))
    plt.axis('off')
    plt.imshow(image, cmap='gray')
    plt.title('Label: %i' % label)
    plt.show()

def list_error_examples(X, Y, weights, layers_confs, samples):
    N = X.shape[1]
    A3 = predict(X, weights, layers_confs)
    res = A3 == Y
    errors = np.where(res == False)
    num = len(errors[0]) if len(errors[0]) < samples else samples

    print("Errors: ")
    for i in range(num):
        show_image(X_train[:, errors[1][i]].reshape(8, 8), errors[0][i])

list_error_examples(X_test, Y_test, weights, layers_confs, 10)
# Out:
# Errors:

# %% [markdown]
# ## TBD: Generalize the Fit function to accept any number of layers.
# Currently fit is hardcoded for a 3 Layer neural network, with Relu Activation for L1 and L2 and Sigmoid activation for L3. Generalize the fit  to accept any layer and activation functions. You can use following sequence of steps to achieve this.
#
# ### TBD 1.  Change layer_dims to layer_confs, previously it was just a list of numbers but now it will be a list of tuples (number_of_nodes, activation_function). E.g layer_confs for existing NN will be. \[ (64, None), (40, relu), (20, relu), (10, sigmoid) \]
#
# ### TBD 2.  Modify init_weights function to initilaize a general weights setting using layer_confs
#
# ### TBD 3.  Modify fit function to use layer_confs to loop to go forward and backward.
#
# ### TBD 4.  Use this general function to test the existing 3 layer configuration and see if you get same accuracy results

# %%
# Neural Net v2 with 3 hidden layers
input_layer = (64, None)
h1 = (40, relu)
h2 = (40, relu)
h3 = (20, relu)
output_layer = (10, sigmoid)
layers_confs = [input_layer, h1, h2, h3, output_layer]

weights = fit(X_train, Y_train, layers_confs, num_iterations = 10000, print_cost=True)
# Out:
# Cost after iteration 0: 6.931568237266486
# Cost after iteration 100: 5.928535693678534
# Cost after iteration 200: 5.232853165865719
# Cost after iteration 300: 4.740148624767148
# Cost after iteration 400: 4.379434839445606
# Cost after iteration 500: 4.0988466457290365
# Cost after iteration 600: 3.645201349727705
# Cost after iteration 700: 3.2543784967300615
# Cost after iteration 800: 3.2540601762007846
# Cost after iteration 900: 3.253792533474232
# Cost after iteration 1000: 3.2535098267556206
# Cost after iteration 1100: 3.253206160600676
# Cost after iteration 1200: 3.252875904095806
# Cost after iteration 1300: 3.2525125986302332
# Cost after iteration 1400: 3.252108694715514
# Cost after iteration 1500: 3.25165526559653
# Cost after iteration 1600: 3.251141556451091
# Cost after iteration 1700: 3.250554475828263
# Cost after iteration 1800: 3.2498778420316254
# Cost after iteration 1900: 3.2490914397640753
# Cost after iteration 2000: 3.248169616140306
# Cost after iteration 2100: 3.2470792210221293
# Cost after iteration 2200: 3.2457768028264615
# Cost after iteration 2300: 3.24420424546448
# Cost after iteration 2400: 3.242281878731883
# Cost after iteration 2500: 3.2398979009244906
# Cost after iteration 2600: 3.2368907013290076
# Cost after iteration 2700: 3.233019065230896
# Cost after iteration 2800: 3.227912536594918
# Cost after iteration 2900: 3.220993946078384
# Cost after iteration 3000: 3.2113786245339515
# Cost after iteration 3100: 3.197687217693395
# Cost after iteration 3200: 3.1775940559168374
# Cost after iteration 3300: 3.149689832093762
# Cost after iteration 3400: 3.1164317869632034
# Cost after iteration 3500: 3.080943816952308
# Cost after iteration 3600: 3.0458646986525766
# Cost after iteration 3700: 3.011442537228575
# Cost after iteration 3800: 2.975596350600757
# Cost after iteration 3900: 2.938990224986279
# Cost after iteration 4000: 2.905741574117242
# Cost after iteration 4100: 2.8755319041128655
# Cost after iteration 4200: 2.847591136893584
# Cost after iteration 4300: 2.8221625429611086
# Cost after iteration 4400: 2.7990285874924217
# Cost after iteration 4500: 2.7779430921883574
# Cost after iteration 4600: 2.758619049657998
# Cost after iteration 4700: 2.740881304674184
# Cost after iteration 4800: 2.724506210643333
# Cost after iteration 4900: 2.7093584617955155
# Cost after iteration 5000: 2.6952607223833245
# Cost after iteration 5100: 2.6820891900302293
# Cost after iteration 5200: 2.670125246134164
# Cost after iteration 5300: 2.6589676284430492
# Cost after iteration 5400: 2.6484789939653584
# Cost after iteration 5500: 2.6385791530596197
# Cost after iteration 5600: 2.629180688290987
# Cost after iteration 5700: 2.6202618851930963
# Cost after iteration 5800: 2.6117852504634755
# Cost after iteration 5900: 2.603689656721912
# Cost after iteration 6000: 2.5960686230797574
# Cost after iteration 6100: 2.5889168361097563
# Cost after iteration 6200: 2.5819626967757947
# Cost after iteration 6300: 2.5752446166345933
# Cost after iteration 6400: 2.568662174550499
# Cost after iteration 6500: 2.5622009833751433
# Cost after iteration 6600: 2.5556234165960663
# Cost after iteration 6700: 2.549068261742689
# Cost after iteration 6800: 2.542549999899389
# Cost after iteration 6900: 2.535989630603887
# Cost after iteration 7000: 2.5294134119873695
# Cost after iteration 7100: 2.522700948334168
# Cost after iteration 7200: 2.51572178576142
# Cost after iteration 7300: 2.508415090485426
# Cost after iteration 7400: 2.5077045233671202
# Cost after iteration 7500: 2.5007837138117144
# Cost after iteration 7600: 2.4919607570926963
# Cost after iteration 7700: 2.480251504203062
# Cost after iteration 7800: 2.464438250258558
# Cost after iteration 7900: 2.4418936303598153
# Cost after iteration 8000: 2.4082425381700334
# Cost after iteration 8100: 2.3578819261738326
# Cost after iteration 8200: 2.297363570777036
# Cost after iteration 8300: 2.2460629475648397
# Cost after iteration 8400: 2.21439804552826
# Cost after iteration 8500: 2.19209259018469
# Cost after iteration 8600: 2.1706955270324575
# Cost after iteration 8700: 2.14731750917514
# Cost after iteration 8800: 2.120951262927926
# Cost after iteration 8900: 2.092553346590052
# Cost after iteration 9000: 2.0573427166561897
# Cost after iteration 9100: 2.0152397011812258
# Cost after iteration 9200: 1.967470880055684
# Cost after iteration 9300: 1.9142230605709416
# Cost after iteration 9400: 1.8606680153341089
# Cost after iteration 9500: 1.8098321235328487
# Cost after iteration 9600: 1.755699465127235
# Cost after iteration 9700: 1.6897711439905034
# Cost after iteration 9800: 1.5961845866498043
# Cost after iteration 9900: 1.4570615810170913
# Accuracy: 0.48997772828507796
# Accuracy: 0.49333333333333335

# %%
accuracy_train = compute_accuracy(X_train, Y_train, weights, layers_confs)
accuracy_test = compute_accuracy(X_test, Y_test, weights, layers_confs)
list_error_examples(X_test, Y_test, weights, layers_confs, 10)
# Out:
# Accuracy: 0.48997772828507796
# Accuracy: 0.49333333333333335
# Errors:
